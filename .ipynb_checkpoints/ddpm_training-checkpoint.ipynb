# %%
import torch
import torch.nn as nn
import torchvision.datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
import numpy as np
import matplotlib.pyplot as plt
#%matplotlib inline

# %%
from src.diffusion import Diffusion
from src.unet import UNet
from src.utils import ASL_mnist, show_dataset_images, show_samples, numel

# %%
dataset_path = './datasets'
batch_size = 256

image_channels = 1
image_size = 28

# %%
if torch.cuda.is_available():
  device = 'cuda'
  print('CUDA')
else:
  device = 'cpu'
  print('CPU')
# Out:
# CUDA

# %%
transform = transforms.Compose([
    transforms.Lambda(lambda t: (t/255.)*2. - 1)
])

reverse_transform = transforms.Compose([
    transforms.Lambda(lambda t: t.detach().cpu().permute(1, 2, 0).numpy())
])

# %%
train_dataset = ASL_mnist(dataset_path, transform=transform)
train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)

# %%
show_dataset_images(train_dataset, reverse_transform)

# %%
ddpm_narrow = Diffusion(UNet(channel_mults=[8, 24, 32], attention_heads=[None, None, None]), device)
ddpm_attn = Diffusion(UNet(channel_mults=[8, 24, 32], attention_heads=[None, 1, 1]), device)
ddpm_wide = Diffusion(UNet(channel_mults=[16, 32, 64], attention_heads=[None, None, None]), device)

print(f'Number of trainable parameters in a narrow model without attention: {numel(ddpm_narrow.model)}')
print(f'Number of trainable parameters in a narrow model with attention: {numel(ddpm_attn.model)}')
print(f'Number of trainable parameters in a wide model without attention: {numel(ddpm_wide.model)}')
# Out:
# Number of trainable parameters in a narrow model without attention: 165229
# Number of trainable parameters in a narrow model with attention: 184901
# Number of trainable parameters in a wide model without attention: 532925

# %%
import time
from tqdm.auto import tqdm

def train_for_n_epochs(model, data_loader, epochs=1, lr=1e-3):
    start_time = time.time()
    for i in tqdm(range(epochs)):
        if i%20 == 0:
            print(f'result after training for {i} epochs')
            show_samples(model, reverse_transform)
            print("--- %s seconds ---" % (time.time() - start_time))   
        model.diffusion_train_epoch(data_loader, lr=lr)
    print(f'result after training for {epochs} epochs')
    show_samples(model, reverse_transform)
    print("--- %s seconds ---" % (time.time() - start_time))

# %%
train_for_n_epochs(ddpm_wide, train_loader, epochs=20, lr=1e-3)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# result after training for 0 epochs
# --- 1.5770010948181152 seconds ---
# result after training for 20 epochs
# --- 504.0323829650879 seconds ---

# %%
train_for_n_epochs(ddpm_wide, train_loader, epochs=20, lr=6e-4)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# result after training for 0 epochs
# --- 1.609811544418335 seconds ---
# result after training for 20 epochs
# --- 506.0237205028534 seconds ---

# %%
train_for_n_epochs(ddpm_wide, train_loader, epochs=20, lr=1e-5)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# result after training for 0 epochs
# --- 1.8959510326385498 seconds ---
# result after training for 10 epochs
# --- 251.55642914772034 seconds ---

# %%
train_for_n_epochs(ddpm_wide, train_loader, epochs=20, lr=1e-6)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# result after training for 0 epochs
# --- 1.7828502655029297 seconds ---
# result after training for 20 epochs
# --- 506.1922721862793 seconds ---

# %%
plt.plot(ddpm_wide.results['loss_history'], color='red', label='wide')
#plt.plot(ddpm_attn.results['loss_history'], color='blue', label='attn')
plt.yscale('log')
plt.legend()
plt.grid()
plt.show()

# %%
#ddpm_narrow.save_model_as('narrow_model_state')
#ddpm_attn.save_model_as('attn_model_state')

# %%
ddpm_wide.save_model_as('wide_model_state')

# %%
w_list = [0., .5, 1.5]
for w in w_list:
    print(f'w = {w}')
    #show_samples(ddpm_attn, reverse_transform, w=w)
    show_samples(ddpm_wide, reverse_transform, w=w)
# Out:
# w = 0.0
# w = 0.5
# w = 1.5
